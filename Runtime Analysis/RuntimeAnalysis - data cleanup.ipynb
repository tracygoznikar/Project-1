# %% [markdown]
# Runtime Analysis - cleanup

# %%
# dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import  scipy.stats as st

# %%
#load the csv file
df = pd.read_csv('/Users/medinai/Desktop/Project-1/MoviesOnStreamingPlatforms_updated.csv')
df
# Out:
#        Unnamed: 0     ID                           Title  Year  Age  IMDb  \
# 0               0      1                       Inception  2010  13+   8.8
# 1               1      2                      The Matrix  1999  18+   8.7
# 2               2      3          Avengers: Infinity War  2018  13+   8.5
# 3               3      4              Back to the Future  1985   7+   8.5
# 4               4      5  The Good, the Bad and the Ugly  1966  18+   8.8
# ...           ...    ...                             ...   ...  ...   ...
# 16739       16739  16740       The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740       16740  16741                  The Poof Point  2001   7+   4.7
# 16741       16741  16742           Sharks of Lost Island  2013  NaN   5.7
# 16742       16742  16743              Man Among Cheetahs  2017  NaN   6.6
# 16743       16743  16744                In Beaver Valley  1950  NaN   NaN
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# ...

# %%
#pick columns needed for Runtime Analysis
new_df = df[['ID', 'Title', 'Year', 'IMDb', 'Rotten Tomatoes', 'Netflix', 'Hulu', 
             'Prime Video', 'Disney+', 'Runtime']]
new_df
# Out:
#           ID                           Title  Year  IMDb Rotten Tomatoes  \
# 0          1                       Inception  2010   8.8             87%
# 1          2                      The Matrix  1999   8.7             87%
# 2          3          Avengers: Infinity War  2018   8.5             84%
# 3          4              Back to the Future  1985   8.5             96%
# 4          5  The Good, the Bad and the Ugly  1966   8.8             97%
# ...      ...                             ...   ...   ...             ...
# 16739  16740       The Ghosts of Buxley Hall  1980   6.2             NaN
# 16740  16741                  The Poof Point  2001   4.7             NaN
# 16741  16742           Sharks of Lost Island  2013   5.7             NaN
# 16742  16743              Man Among Cheetahs  2017   6.6             NaN
# 16743  16744                In Beaver Valley  1950   NaN             NaN
#
#        Netflix  Hulu  Prime Video  Disney+  Runtime
# ...

# %%
#Drop NaN values from Runtime, Rotten Tomatoes and IMDb columns
clean_df = new_df.dropna(subset=['Runtime', 'Rotten Tomatoes', 'IMDb'])
clean_df.count()
clean_df
# Out:
#           ID                           Title  Year  IMDb Rotten Tomatoes  \
# 0          1                       Inception  2010   8.8             87%
# 1          2                      The Matrix  1999   8.7             87%
# 2          3          Avengers: Infinity War  2018   8.5             84%
# 3          4              Back to the Future  1985   8.5             96%
# 4          5  The Good, the Bad and the Ugly  1966   8.8             97%
# ...      ...                             ...   ...   ...             ...
# 16671  16672          George of the Jungle 2  2003   3.3             17%
# 16677  16678                   That Darn Cat  1997   4.7             13%
# 16687  16688                          Kazaam  1996   3.0              6%
# 16705  16706                Meet the Deedles  1998   4.1              7%
# 16719  16720                      Pocahontas  1995   5.3             55%
#
#        Netflix  Hulu  Prime Video  Disney+  Runtime
# ...

# %%
# imdb = clean_df[['IMDb', 'Runtime']]
# # x_axis = cleandf[['Runtime']]
# # y_axis = clean_df['IMDb']
# imdb.plot.line()

# %%
clean_df.to_csv(r"/Users/medinai/Desktop/Project-1/Runtime Analysis/clean_df.csv", index=False)
